# %% [markdown]
# <a href="https://colab.research.google.com/github/kapilvarunbabu-g/telegram/blob/main/Telegrambot1/Telegrambot1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#AIMER Society - Indian Servers
# !pip install pyTelegramBotAPI

#!pip install openai
# !pip install google-generativeai #For Google Gemini #AIMERS
#!pip install anthropic
TelegramBOT_TOKEN = '8011093624:AAFe8hmgmRad1o4bB5rckvYwO7tUWoHexFo'
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.3/48.3 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.2/304.2 kB 13.4 MB/s eta 0:00:00
# ...

# %%
#general

#Latest version #Gemini API #AIMER Society #IndianServers
import telebot
import base64
import os
from google import genai
from google.genai import types

from google import genai

client = genai.Client(api_key='AIzaSyARqytfnagtuVYcpe6Z0DI2Utz7QOJUj6U')

model = "gemini-2.0-flash"

fullreply=""

bot = telebot.TeleBot(TelegramBOT_TOKEN)

@bot.message_handler(commands=['start', 'help'])
def send_welcome(message):
    bot.reply_to(message, "Welcome! Indian Servers AI Powerful BOT, Ask your questions related to Anything")

@bot.message_handler(func=lambda message: True)
def handle_message(message):
    print(message)
    response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=message.text,
)

    bot.reply_to(message,response.text)

bot.polling()
